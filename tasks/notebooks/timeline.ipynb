# %%
import re
from collections import defaultdict

# %%
KB_ID = 'concepts'

# %% [markdown]
# ### Setup Text Extraction Method

# %%
import nltk
from extr.entities import create_entity_extractor, KnowledgeBaseEntityLinker, EntityAnnotator
from extr.relations import RelationExtractor
from extr.entities.context import ConText

from labels.entity_patterns import patterns
from labels.kb import kb as kb_patterns
from labels.relation_patterns import relation_patterns
from knowledge.kb import kb
from rules.context import rule_grouping

entity_extractor = create_entity_extractor(patterns, kb_patterns)
relation_extractor = RelationExtractor(relation_patterns)
conText = ConText(
    rule_grouping=rule_grouping,
    word_tokenizer=nltk.tokenize.word_tokenize
)
entity_linker = KnowledgeBaseEntityLinker(
    attribute_label=KB_ID,
    kb=kb
)
entity_annotator = EntityAnnotator()

def extract_data(instance: str):
    entities = conText.apply(
        instance,
        entity_linker.link(
            entity_extractor.get_entities(instance)
        ),
        filter_out_rule_labels=True
    )
    
    relations = relation_extractor.extract(
        entity_annotator.annotate(instance, entities),
        entities
    )

    return entities, relations

# %% [markdown]
# ### Extract Entities / Relations / Identify Context / Link Entities

# %%
instances = []
with open('../data/2/2022_w1_g401437632.txt', 'r') as source_file:
    instances = source_file.read().split('\n')

# %%
observations = []
for instance in instances:
    entities, relations = extract_data(instance)

    observation = {
        'entities': entities,
        'stats': {
            'n_rels': len(relations),
            'n_entities': len(entities)
        }
    }

    for relation in relations:
        definition = relation.definition
        if not definition in observation:
            observation[definition] = []

        observation[definition].append(relation)

    observations.append(observation)

observations[0]
# Out:
# {'entities': [<Entity label="QUANTITY" text="25" span=(85, 87)>,
#   <Entity label="QUANTITY" text="22" span=(78, 80)>,
#   <Entity label="TEAM" text="NYJ" span=(74, 77)>,
#   <Entity label="QUANTITY" text="-3" span=(57, 59)>,
#   <Entity label="TEAM" text="NYJ" span=(53, 56)>,
#   <Entity label="QUANTITY" text="35" span=(47, 49)>,
#   <Entity label="TEAM" text="BLT" span=(43, 46)>,
#   <Entity label="QUANTITY" text="68" span=(29, 31)>,
#   <Entity label="PERIOD" text="1st" span=(9, 12)>,
#   <Entity label="TIME" text="15:00" span=(1, 6)>],
#  'stats': {'n_rels': 4, 'n_entities': 10},
#  'r("PERIOD", "TIME")': [<Relation e1="1st" r="is_at" e2="15:00">],
#  'r("TEAM", "QUANTITY")': [<Relation e1="BLT" r="is_spot_of_ball" e2="35">,
#   <Relation e1="NYJ" r="is_spot_of_ball" e2="-3">,
#   <Relation e1="NYJ" r="is_spot_of_ball" e2="22">]}

# %% [markdown]
# ### Group Events by Period and Time

# %%
from collections import defaultdict

group_by_period = defaultdict(list)

is_at_key = 'r("PERIOD", "TIME")'

for observation in observations:
    if not is_at_key in observation:
        continue

    is_at = observation[is_at_key][0]
    e1 = is_at.e1
    e2 = is_at.e2
    key = f'{e1.text}-{e2.text}'

    group_by_period[key].append(observation)

# %% [markdown]
# ### Build Time-Series

# %%
from typing import List
from extr import Entity, Relation

def get_data_from_entities(entities: List[Entity]):
    data = {}

    scores = [
        (entity)
        for entity in entities
        if entity.label=='SCORE'
    ]

    if len(scores) > 0:
        data['score'] = scores[0].text
    
    return data

def get_period_and_time(is_at: Relation):
    def normalize_time(time: str):
        parts = time.split(':')
        mins = (15 - int(parts[0]))
        secs =  int(parts[1])

        return float(f'{mins}.{secs}')

    e1 = is_at.e1
    e2 = is_at.e2
    return e1.text, normalize_time(e2.text)

def get_side_and_spot(is_spot_of_ball: Relation, offset_team: str):
    e1 = is_spot_of_ball.e1
    e2 = is_spot_of_ball.e2

    spot_of_ball = int(e2.text)
    if e1.text == offset_team:
        spot_of_ball = 50 + (50 - spot_of_ball)
    
    return e1.text, spot_of_ball

# %%
timeline = []
previous = []

i = 1

is_at_key = 'r("PERIOD", "TIME")'

for kbs in group_by_period.values():
    for seq_p, kb in enumerate(kbs):
        entities = kb['entities']

        extracted_entity_data = get_data_from_entities(kb['entities'])
        period, time = get_period_and_time(kb[is_at_key][0])

        yard_lines = []
        if not 'r("TEAM", "QUANTITY")' in kb:
            yard_lines = previous
        else:
            yard_lines = kb['r("TEAM", "QUANTITY")']
            previous = kb['r("TEAM", "QUANTITY")']

        for seq_l, loc in enumerate(yard_lines):
            side, spot_of_ball = get_side_and_spot(loc, 'BLT')

            data = {
                'period': period,
                'time': time,
                'side': side,
                'spot': spot_of_ball,
                'label': i
            }

            data.update(extracted_entity_data)

            timeline.append(data)

            i += 1

timeline
# Out:
# [{'period': '1st', 'time': 0.0, 'side': 'BLT', 'spot': 65, 'label': 1},
#  {'period': '1st', 'time': 0.0, 'side': 'NYJ', 'spot': -3, 'label': 2},
#  {'period': '1st', 'time': 0.0, 'side': 'NYJ', 'spot': 22, 'label': 3},
#  {'period': '1st', 'time': 1.55, 'side': 'NYJ', 'spot': 41, 'label': 4},
#  {'period': '1st', 'time': 1.55, 'side': 'NYJ', 'spot': 41, 'label': 5},
#  {'period': '1st', 'time': 1.18, 'side': 'NYJ', 'spot': 46, 'label': 6},
#  {'period': '1st', 'time': 1.1, 'side': 'NYJ', 'spot': 46, 'label': 7},
#  {'period': '1st', 'time': 2.52, 'side': 'BLT', 'spot': 81, 'label': 8},
#  {'period': '1st', 'time': 2.52, 'side': 'BLT', 'spot': 72, 'label': 9},
#  {'period': '1st', 'time': 2.42, 'side': 'BLT', 'spot': 68, 'label': 10},
#  {'period': '1st', 'time': 2.19, 'side': 'BLT', 'spot': 64, 'label': 11},
#  {'period': '1st', 'time': 3.41, 'side': 'BLT', 'spot': 60, 'label': 12},
#  {'period': '1st', 'time': 3.1, 'side': 'BLT', 'spot': 60, 'label': 13},
#  {'period': '1st', 'time': 4.19, 'side': 'BLT', 'spot': 52, 'label': 14},
#  {'period': '1st', 'time': 5.17, 'side': 'BLT', 'spot': 51, 'label': 15},
#  {'period': '1st', 'time': 6.56, 'side': 'BLT', 'spot': 51, 'label': 16},
#  {'period': '1st', 'time': 6.55, 'side': 'NYJ', 'spot': 11, 'label': 17},
#  {'period': '1st', 'time': 6.44, 'side': 'NYJ', 'spot': 9, 'label': 18},
#  {'period': '1st', 'time': 6.11, 'side': 'NYJ', 'spot': 12, 'label': 19},
#  {'period': '1st', 'time': 7.31, 'side': 'NYJ', 'spot': 12, 'label': 20},
#  {'period': '1st', 'time': 7.27, 'side': 'NYJ', 'spot': 18, 'label': 21},
#  {'period': '1st', 'time': 8.5, 'side': 'NYJ', 'spot': 18, 'label': 22},
#  {'period': '1st', 'time': 8.16, 'side': 'NYJ', 'spot': 18, 'label': 23},
#  {'period': '1st', 'time': 8.1, 'side': 'BLT', 'spot': 66, 'label': 24},
#  {'period': '1st', 'time': 8.5, 'side': 'BLT', 'spot': 66, 'label': 25},
#  {'period': '1st', 'time': 8.1, 'side': 'BLT', 'spot': 65, 'label': 26},
#  {'period': '1st', 'time': 9.12, 'side': 'BLT', 'spot': 65, 'label': 27},
#  {'period': '1st', 'time': 9.8, 'side': 'NYJ', 'spot': 17, 'label': 28},
#  {'period': '1st', 'time': 9.1, 'side': 'NYJ', 'spot': 41, 'label': 29},
#  {'period': '1st', 'time': 10.21, 'side': 'NYJ', 'spot': 44, 'label': 30},
#  {'period': '1st', 'time': 10.21, 'side': 'NYJ', 'spot': 42, 'label': 31},
#  {'period': '1st', 'time': 11.56, 'side': 'NYJ', 'spot': 46, 'label': 32},
#  {'period': '1st', 'time': 11.56, 'side': 'NYJ', 'spot': 13, 'label': 33},
#  {'period': '1st', 'time': 11.55, 'side': 'NYJ', 'spot': 14, 'label': 34},
#  {'period': '1st', 'time': 11.8, 'side': 'NYJ', 'spot': 6, 'label': 35},
#  {'period': '1st', 'time': 12.23, 'side': 'NYJ', 'spot': 6, 'label': 36},
#  {'period': '1st',
#   'time': 12.16,
#   'side': 'NYJ',
#   'spot': 6,
#   'label': 37,
#   'score': 'field goal'},
#  {'period': '1st', 'time': 12.16, 'side': 'BLT', 'spot': 65, 'label': 38},
#  {'period': '1st', 'time': 12.16, 'side': 'BLT', 'spot': 65, 'label': 39},
#  {'period': '1st', 'time': 12.11, 'side': 'BLT', 'spot': 65, 'label': 40},
#  {'period': '1st', 'time': 12.6, 'side': 'NYJ', 'spot': 34, 'label': 41},
#  {'period': '1st', 'time': 13.0, 'side': 'BLT', 'spot': 84, 'label': 42},
#  {'period': '1st', 'time': 14.53, 'side': 'BLT', 'spot': 73, 'label': 43},
#  {'period': '1st', 'time': 14.12, 'side': 'BLT', 'spot': 71, 'label': 44},
#  {'period': '1st', 'time': 15.25, 'side': 'BLT', 'spot': 68, 'label': 45},
#  {'period': '1st', 'time': 15.0, 'side': 'BLT', 'spot': 68, 'label': 46},
#  {'period': '2nd', 'time': 0.0, 'side': 'BLT', 'spot': 68, 'label': 47},
#  {'period': '2nd', 'time': 1.55, 'side': 'NYJ', 'spot': 12, 'label': 48},
#  {'period': '2nd', 'time': 1.55, 'side': 'NYJ', 'spot': 29, 'label': 49},
#  {'period': '2nd', 'time': 1.45, 'side': 'NYJ', 'spot': 44, 'label': 50},
#  {'period': '2nd', 'time': 1.18, 'side': 'BLT', 'spot': 55, 'label': 51},
#  {'period': '2nd', 'time': 2.36, 'side': 'BLT', 'spot': 59, 'label': 52},
#  {'period': '2nd', 'time': 2.0, 'side': 'BLT', 'spot': 67, 'label': 53},
#  {'period': '2nd', 'time': 3.19, 'side': 'BLT', 'spot': 67, 'label': 54},
#  {'period': '2nd', 'time': 4.39, 'side': 'BLT', 'spot': 73, 'label': 55},
#  {'period': '2nd', 'time': 4.0, 'side': 'BLT', 'spot': 73, 'label': 56},
#  {'period': '2nd',
#   'time': 5.54,
#   'side': 'BLT',
#   'spot': 73,
#   'label': 57,
#   'score': 'field goal'},
#  {'period': '2nd', 'time': 5.51, 'side': 'BLT', 'spot': 60, 'label': 58},
#  {'period': '2nd', 'time': 5.17, 'side': 'NYJ', 'spot': 49, 'label': 59},
#  {'period': '2nd', 'time': 6.42, 'side': 'NYJ', 'spot': 49, 'label': 60},
#  {'period': '2nd', 'time': 7.59, 'side': 'BLT', 'spot': 51, 'label': 61},
#  {'period': '2nd', 'time': 7.15, 'side': 'BLT', 'spot': 51, 'label': 62},
#  {'period': '2nd', 'time': 7.7, 'side': 'NYJ', 'spot': 11, 'label': 63},
#  {'period': '2nd', 'time': 7.1, 'side': 'NYJ', 'spot': 25, 'label': 64},
#  {'period': '2nd', 'time': 7.1, 'side': 'NYJ', 'spot': 30, 'label': 65},
#  {'period': '2nd', 'time': 9.53, 'side': 'NYJ', 'spot': 36, 'label': 66},
#  {'period': '2nd', 'time': 9.17, 'side': 'NYJ', 'spot': 30, 'label': 67},
#  {'period': '2nd', 'time': 10.31, 'side': 'NYJ', 'spot': 29, 'label': 68},
#  {'period': '2nd', 'time': 11.55, 'side': 'NYJ', 'spot': 29, 'label': 69},
#  {'period': '2nd', 'time': 11.49, 'side': 'BLT', 'spot': 70, 'label': 70},
#  {'period': '2nd', 'time': 11.49, 'side': 'BLT', 'spot': 62, 'label': 71},
#  {'period': '2nd', 'time': 11.41, 'side': 'BLT', 'spot': 62, 'label': 72},
#  {'period': '2nd', 'time': 11.35, 'side': 'BLT', 'spot': 62, 'label': 73},
#  {'period': '2nd', 'time': 11.29, 'side': 'NYJ', 'spot': 25, 'label': 74},
#  {'period': '2nd', 'time': 12.45, 'side': 'NYJ', 'spot': 25, 'label': 75},
#  {'period': '2nd', 'time': 12.45, 'side': 'BLT', 'spot': 65, 'label': 76},
#  {'period': '2nd', 'time': 12.4, 'side': 'NYJ', 'spot': 30, 'label': 77},
#  {'period': '2nd', 'time': 12.14, 'side': 'BLT', 'spot': 52, 'label': 78},
#  {'period': '2nd', 'time': 13.34, 'side': 'BLT', 'spot': 55, 'label': 79},
#  {'period': '2nd', 'time': 13.0, 'side': 'BLT', 'spot': 55, 'label': 80},
#  {'period': '2nd', 'time': 13.0, 'side': 'BLT', 'spot': 68, 'label': 81},
#  {'period': '2nd', 'time': 14.26, 'side': 'BLT', 'spot': 73, 'label': 82},
#  {'period': '2nd', 'time': 14.2, 'side': 'BLT', 'spot': 73, 'label': 83},
#  {'period': '2nd', 'time': 14.2, 'side': 'BLT', 'spot': 73, 'label': 84},
#  {'period': '2nd', 'time': 14.16, 'side': 'BLT', 'spot': 73, 'label': 85},
#  {'period': '2nd', 'time': 14.15, 'side': 'BLT', 'spot': 79, 'label': 86},
#  {'period': '2nd', 'time': 14.15, 'side': 'BLT', 'spot': 72, 'label': 87},
#  {'period': '2nd', 'time': 14.15, 'side': 'BLT', 'spot': 73, 'label': 88},
#  {'period': '2nd',
#   'time': 15.24,
#   'side': 'BLT',
#   'spot': 79,
#   'label': 89,
#   'score': 'field goal'},
#  {'period': '2nd',
#   'time': 15.24,
#   'side': 'BLT',
#   'spot': 72,
#   'label': 90,
#   'score': 'field goal'},
#  {'period': '2nd',
#   'time': 15.24,
#   'side': 'BLT',
#   'spot': 73,
#   'label': 91,
#   'score': 'field goal'},
#  {'period': '2nd', 'time': 15.24, 'side': 'NYJ', 'spot': 35, 'label': 92},
#  {'period': '2nd', 'time': 15.24, 'side': 'NYJ', 'spot': 35, 'label': 93},
#  {'period': '2nd', 'time': 15.23, 'side': 'BLT', 'spot': 72, 'label': 94},
#  {'period': '2nd', 'time': 15.0, 'side': 'BLT', 'spot': 72, 'label': 95},
#  {'period': '3rd', 'time': 0.0, 'side': 'NYJ', 'spot': 35, 'label': 96},
#  {'period': '3rd', 'time': 1.59, 'side': 'BLT', 'spot': 73, 'label': 97},
#  {'period': '3rd', 'time': 1.21, 'side': 'BLT', 'spot': 73, 'label': 98},
#  {'period': '3rd', 'time': 1.15, 'side': 'BLT', 'spot': 65, 'label': 99},
#  {'period': '3rd', 'time': 2.32, 'side': 'BLT', 'spot': 64, 'label': 100},
#  {'period': '3rd', 'time': 3.58, 'side': 'BLT', 'spot': 64, 'label': 101},
#  {'period': '3rd', 'time': 3.5, 'side': 'BLT', 'spot': 64, 'label': 102},
#  {'period': '3rd', 'time': 3.44, 'side': 'BLT', 'spot': 64, 'label': 103},
#  {'period': '3rd', 'time': 3.37, 'side': 'NYJ', 'spot': 15, 'label': 104},
#  {'period': '3rd', 'time': 4.55, 'side': 'NYJ', 'spot': 15, 'label': 105},
#  {'period': '3rd', 'time': 4.16, 'side': 'NYJ', 'spot': 24, 'label': 106},
#  {'period': '3rd', 'time': 5.3, 'side': 'NYJ', 'spot': 44, 'label': 107},
#  {'period': '3rd', 'time': 5.24, 'side': 'NYJ', 'spot': 29, 'label': 108},
#  {'period': '3rd', 'time': 6.48, 'side': 'NYJ', 'spot': 23, 'label': 109},
#  {'period': '3rd', 'time': 6.13, 'side': 'NYJ', 'spot': 17, 'label': 110},
#  {'period': '3rd', 'time': 7.29, 'side': 'NYJ', 'spot': 18, 'label': 111},
#  {'period': '3rd', 'time': 7.3, 'side': 'NYJ', 'spot': 17, 'label': 112},
#  {'period': '3rd', 'time': 8.14, 'side': 'NYJ', 'spot': 17, 'label': 113},
#  {'period': '3rd', 'time': 8.14, 'side': 'BLT', 'spot': 65, 'label': 114},
#  {'period': '3rd', 'time': 8.14, 'side': 'NYJ', 'spot': 26, 'label': 115},
#  {'period': '3rd', 'time': 9.38, 'side': 'NYJ', 'spot': 26, 'label': 116},
#  {'period': '3rd', 'time': 9.3, 'side': 'NYJ', 'spot': 20, 'label': 117},
#  {'period': '3rd', 'time': 9.3, 'side': 'NYJ', 'spot': 26, 'label': 118},
#  {'period': '3rd', 'time': 9.5, 'side': 'NYJ', 'spot': 33, 'label': 119},
#  {'period': '3rd', 'time': 10.31, 'side': 'NYJ', 'spot': 39, 'label': 120},
#  {'period': '3rd', 'time': 11.54, 'side': 'NYJ', 'spot': 39, 'label': 121},
#  {'period': '3rd', 'time': 11.48, 'side': 'BLT', 'spot': 88, 'label': 122},
#  {'period': '3rd', 'time': 11.37, 'side': 'BLT', 'spot': 88, 'label': 123},
#  {'period': '3rd', 'time': 11.34, 'side': 'BLT', 'spot': 73, 'label': 124},
#  {'period': '3rd', 'time': 12.51, 'side': 'BLT', 'spot': 65, 'label': 125},
#  {'period': '3rd', 'time': 12.11, 'side': 'BLT', 'spot': 57, 'label': 126},
#  {'period': '3rd', 'time': 12.11, 'side': 'BLT', 'spot': 55, 'label': 127},
#  {'period': '3rd', 'time': 13.6, 'side': 'BLT', 'spot': 57, 'label': 128},
#  {'period': '3rd', 'time': 13.6, 'side': 'BLT', 'spot': 55, 'label': 129},
#  {'period': '3rd', 'time': 14.32, 'side': 'BLT', 'spot': 65, 'label': 130},
#  {'period': '3rd', 'time': 14.32, 'side': 'NYJ', 'spot': -5, 'label': 131},
#  {'period': '3rd', 'time': 14.32, 'side': 'NYJ', 'spot': 18, 'label': 132},
#  {'period': '3rd', 'time': 14.32, 'side': 'NYJ', 'spot': 18, 'label': 133},
#  {'period': '3rd', 'time': 14.3, 'side': 'NYJ', 'spot': 36, 'label': 134},
#  {'period': '3rd', 'time': 14.0, 'side': 'NYJ', 'spot': 26, 'label': 135},
#  {'period': '3rd', 'time': 14.0, 'side': 'NYJ', 'spot': 34, 'label': 136},
#  {'period': '3rd', 'time': 15.36, 'side': 'NYJ', 'spot': 34, 'label': 137},
#  {'period': '3rd', 'time': 15.32, 'side': 'NYJ', 'spot': 48, 'label': 138},
#  {'period': '3rd', 'time': 15.5, 'side': 'BLT', 'spot': 60, 'label': 139},
#  {'period': '3rd', 'time': 15.0, 'side': 'BLT', 'spot': 60, 'label': 140},
#  {'period': '4th', 'time': 0.0, 'side': 'BLT', 'spot': 75, 'label': 141},
#  {'period': '4th', 'time': 1.33, 'side': 'BLT', 'spot': 78, 'label': 142},
#  {'period': '4th', 'time': 1.1, 'side': 'BLT', 'spot': 84, 'label': 143},
#  {'period': '4th', 'time': 1.1, 'side': 'BLT', 'spot': 85, 'label': 144},
#  {'period': '4th', 'time': 1.3, 'side': 'BLT', 'spot': 77, 'label': 145},
#  {'period': '4th', 'time': 2.17, 'side': 'BLT', 'spot': 72, 'label': 146},
#  {'period': '4th', 'time': 2.17, 'side': 'BLT', 'spot': 77, 'label': 147},
#  {'period': '4th', 'time': 3.48, 'side': 'BLT', 'spot': 83, 'label': 148},
#  {'period': '4th', 'time': 3.1, 'side': 'BLT', 'spot': 66, 'label': 149},
#  {'period': '4th', 'time': 4.13, 'side': 'BLT', 'spot': 62, 'label': 150},
#  {'period': '4th', 'time': 5.25, 'side': 'BLT', 'spot': 62, 'label': 151},
#  {'period': '4th', 'time': 5.18, 'side': 'BLT', 'spot': 62, 'label': 152},
#  {'period': '4th', 'time': 5.14, 'side': 'NYJ', 'spot': 19, 'label': 153},
#  {'period': '4th', 'time': 5.14, 'side': 'NYJ', 'spot': 32, 'label': 154},
#  {'period': '4th', 'time': 5.5, 'side': 'NYJ', 'spot': 49, 'label': 155},
#  {'period': '4th', 'time': 6.43, 'side': 'NYJ', 'spot': 49, 'label': 156},
#  {'period': '4th', 'time': 6.41, 'side': 'BLT', 'spot': 55, 'label': 157},
#  {'period': '4th', 'time': 6.5, 'side': 'BLT', 'spot': 63, 'label': 158},
#  {'period': '4th', 'time': 7.44, 'side': 'BLT', 'spot': 63, 'label': 159},
#  {'period': '4th', 'time': 7.39, 'side': 'BLT', 'spot': 72, 'label': 160},
#  {'period': '4th', 'time': 7.1, 'side': 'BLT', 'spot': 72, 'label': 161},
#  {'period': '4th', 'time': 7.1, 'side': 'BLT', 'spot': 79, 'label': 162},
#  {'period': '4th', 'time': 8.6, 'side': 'BLT', 'spot': 79, 'label': 163},
#  {'period': '4th', 'time': 8.6, 'side': 'BLT', 'spot': 79, 'label': 164},
#  {'period': '4th', 'time': 9.57, 'side': 'BLT', 'spot': 78, 'label': 165},
#  {'period': '4th', 'time': 9.33, 'side': 'BLT', 'spot': 83, 'label': 166},
#  {'period': '4th', 'time': 10.59, 'side': 'BLT', 'spot': 86, 'label': 167},
#  {'period': '4th', 'time': 10.17, 'side': 'BLT', 'spot': 90, 'label': 168},
#  {'period': '4th', 'time': 11.53, 'side': 'BLT', 'spot': 90, 'label': 169},
#  {'period': '4th', 'time': 11.49, 'side': 'BLT', 'spot': 94, 'label': 170},
#  {'period': '4th', 'time': 11.28, 'side': 'BLT', 'spot': 94, 'label': 171},
#  {'period': '4th', 'time': 11.21, 'side': 'BLT', 'spot': 94, 'label': 172},
#  {'period': '4th', 'time': 11.16, 'side': 'BLT', 'spot': 81, 'label': 173},
#  {'period': '4th', 'time': 11.16, 'side': 'BLT', 'spot': 93, 'label': 174},
#  {'period': '4th', 'time': 11.11, 'side': 'BLT', 'spot': 81, 'label': 175},
#  {'period': '4th', 'time': 11.11, 'side': 'BLT', 'spot': 93, 'label': 176},
#  {'period': '4th', 'time': 11.9, 'side': 'BLT', 'spot': 90, 'label': 177},
#  {'period': '4th', 'time': 12.3, 'side': 'BLT', 'spot': 89, 'label': 178},
#  {'period': '4th', 'time': 13.49, 'side': 'BLT', 'spot': 57, 'label': 179},
#  {'period': '4th', 'time': 13.49, 'side': 'BLT', 'spot': 57, 'label': 180},
#  {'period': '4th', 'time': 13.41, 'side': 'BLT', 'spot': 57, 'label': 181},
#  {'period': '4th', 'time': 13.41, 'side': 'BLT', 'spot': 57, 'label': 182},
#  {'period': '4th', 'time': 13.36, 'side': 'BLT', 'spot': 73, 'label': 183},
#  {'period': '4th', 'time': 13.25, 'side': 'BLT', 'spot': 78, 'label': 184},
#  {'period': '4th', 'time': 13.11, 'side': 'BLT', 'spot': 78, 'label': 185},
#  {'period': '4th', 'time': 13.6, 'side': 'BLT', 'spot': 69, 'label': 186},
#  {'period': '4th', 'time': 13.6, 'side': 'BLT', 'spot': 78, 'label': 187},
#  {'period': '4th', 'time': 13.0, 'side': 'BLT', 'spot': 69, 'label': 188},
#  {'period': '4th', 'time': 13.0, 'side': 'BLT', 'spot': 78, 'label': 189},
#  {'period': '4th', 'time': 14.59, 'side': 'BLT', 'spot': 88, 'label': 190},
#  {'period': '4th', 'time': 14.38, 'side': 'BLT', 'spot': 88, 'label': 191},
#  {'period': '4th', 'time': 14.32, 'side': 'BLT', 'spot': 88, 'label': 192},
#  {'period': '4th',
#   'time': 14.21,
#   'side': 'BLT',
#   'spot': 88,
#   'label': 193,
#   'score': 'TOUCHDOWN'},
#  {'period': '4th', 'time': 14.17, 'side': 'BLT', 'spot': 97, 'label': 194},
#  {'period': '4th', 'time': 14.1, 'side': 'BLT', 'spot': 97, 'label': 195},
#  {'period': '4th', 'time': 14.7, 'side': 'BLT', 'spot': 97, 'label': 196},
#  {'period': '4th', 'time': 14.0, 'side': 'BLT', 'spot': 97, 'label': 197},
#  {'period': '4th', 'time': 15.59, 'side': 'NYJ', 'spot': 35, 'label': 198},
#  {'period': '4th', 'time': 15.59, 'side': 'NYJ', 'spot': 42, 'label': 199},
#  {'period': '4th', 'time': 15.59, 'side': 'NYJ', 'spot': 42, 'label': 200},
#  {'period': '4th', 'time': 15.37, 'side': 'NYJ', 'spot': 43, 'label': 201},
#  {'period': '4th', 'time': 15.9, 'side': 'NYJ', 'spot': 44, 'label': 202},
#  {'period': '4th', 'time': 15.0, 'side': 'NYJ', 'spot': 44, 'label': 203}]

# %%
import matplotlib.pyplot as plt

X = list(map(lambda a: a['norm-time'], timeline))
y = list(map(lambda a: a['yard-line'], timeline))

plt.figure(figsize=(10, 30))
plt.plot(y, X, '.-')

for i, obj in enumerate(timeline):
    plt.annotate(obj['label'], (y[i], X[i]))

plt.axvline(0, color='r', linewidth=.5)
plt.axvline(50, color='k', linewidth=.5)
plt.axvline(100, color='r', linewidth=.5)

for row in timeline:
    if len(row['score']) > 0:
        e = row['score'][0]
        ctypes = list(e.get_attributes_by_label('ctypes'))
        
        if len(ctypes) > 0:
            plt.plot(row['yard-line'], row['norm-time'], 'o', c='r')
        else:
            if e.text == 'TOUCHDOWN':
                plt.plot(row['yard-line'], row['norm-time'], 'o', c='pink')
            else:
                plt.plot(row['yard-line'], row['norm-time'], 'o', c='purple')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 3
#       1 import matplotlib.pyplot as plt
# ----> 3 X = list(map(lambda a: a['norm-time'], timeline))
#       4 y = list(map(lambda a: a['yard-line'], timeline))
#       6 plt.figure(figsize=(10, 30))
#
# Cell In[37], line 3, in <lambda>(a)
#       1 import matplotlib.pyplot as plt
# ----> 3 X = list(map(lambda a: a['norm-time'], timeline))
#       4 y = list(map(lambda a: a['yard-line'], timeline))
#       6 plt.figure(figsize=(10, 30))
#
# KeyError: 'norm-time'
